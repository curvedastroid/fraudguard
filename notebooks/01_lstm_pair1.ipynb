# %% [markdown]
# # LSTM Model — Long Short-Term Memory
# **Owner:** Pair 1
# **Environment:** Google Colab (GPU recommended for training)
# **Depends on:** `data/processed/` — run `00_data_pipeline.ipynb` first
# **Outputs:**
# - `models/lstm/lstm_model.keras`
# - `models/lstm/lstm_history.json`
# - `models/lstm/lstm_metrics.json`
#
# ---
# ### Setup on Google Colab
# 1. Upload the entire `FraudGuard/` folder to Google Drive
# 2. Open this notebook in Colab → Runtime → Change runtime type → **GPU**
# 3. Run the environment cell below to mount Drive

# %%
## ── 0. Environment & paths ───────────────────────────────────────────────
import os, sys

IN_COLAB = os.path.exists('/content')
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    BASE       = '/content/drive/MyDrive/FraudGuard_Parent'
    # Install any missing packages
    os.system('pip install tensorflow scikit-learn matplotlib -q')
else:
    BASE = os.path.abspath(os.path.join(os.path.dirname(os.path.abspath('__file__')), '..'))

DATA_PROC  = os.path.join(BASE, 'data',   'processed')
MODEL_DIR  = os.path.join(BASE, 'models', 'lstm')
os.makedirs(MODEL_DIR, exist_ok=True)

print("BASE      :", BASE)
print("Data      :", DATA_PROC)
print("Model dir :", MODEL_DIR)

import tensorflow as tf
print("TF version:", tf.__version__)
gpus = tf.config.list_physical_devices('GPU')
print("GPUs available:", gpus if gpus else "None (running on CPU)")
# Out:
# Mounted at /content/drive
# BASE      : /content/drive/MyDrive/FraudGuard_Parent
# Data      : /content/drive/MyDrive/FraudGuard_Parent/data/processed
# Model dir : /content/drive/MyDrive/FraudGuard_Parent/models/lstm
# TF version: 2.20.0
# GPUs available: None (running on CPU)

# %%
## ── 1. Load shared processed data ────────────────────────────────────────
import numpy as np, json

X_train = np.load(os.path.join(DATA_PROC, 'X_train.npy'))
X_val   = np.load(os.path.join(DATA_PROC, 'X_val.npy'))
X_test  = np.load(os.path.join(DATA_PROC, 'X_test.npy'))
y_train = np.load(os.path.join(DATA_PROC, 'y_train.npy'))
y_val   = np.load(os.path.join(DATA_PROC, 'y_val.npy'))
y_test  = np.load(os.path.join(DATA_PROC, 'y_test.npy'))

with open(os.path.join(DATA_PROC, 'class_weights.json')) as f:
    class_weights = json.load(f)
    # Convert string keys back to int
    class_weights = {int(k): v for k, v in class_weights.items()}

with open(os.path.join(DATA_PROC, 'meta.json')) as f:
    meta = json.load(f)

SEQ_LEN  = meta['seq_len']
N_FEATS  = meta['n_features']
FEATURES = meta['features']

print(f"X_train : {X_train.shape}")
print(f"X_val   : {X_val.shape}")
print(f"X_test  : {X_test.shape}")
print(f"Class weights: {class_weights}")
# Out:
# X_train : (348676, 5, 15)
# X_val   : (74716, 5, 15)
# X_test  : (74717, 5, 15)
# Class weights: {0: 0.5189063374328813, 1: 13.723079345088161}

# %% [markdown]
# ## 2 · Build the LSTM Model
# Implement a two-layer stacked LSTM with dropout and batch normalisation.
# Both members of the pair should review and agree on the final architecture before training.

# %%
## ── 2.1 Architecture ─────────────────────────────────────────────────────
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Masking
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC

model = Sequential([
    Masking(mask_value=0., input_shape=(SEQ_LEN, N_FEATS)),  # ignores padded steps
    LSTM(64, return_sequences=True, name='lstm_1'),
    BatchNormalization(),
    Dropout(0.3),
    LSTM(32, return_sequences=False, name='lstm_2'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(1, activation='sigmoid', name='output'),
])

model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss='binary_crossentropy',
    metrics=[AUC(name='auc'), 'accuracy'],
)
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/masking.py:48: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ masking (Masking)               │ (None, 5, 15)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 5, 64)          │        20,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 5, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 5, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,313 (130.13 KB)
#  Trainable params: 33,121 (129.38 KB)
#  Non-trainable params: 192 (768.00 B)

# %% [markdown]
# ### Hyperparameter Options (Pair 1 — experiment and compare)
# | Parameter | Default | Try also |
# |-----------|---------|----------|
# | LSTM units (layer 1) | 64 | 32, 128 |
# | LSTM units (layer 2) | 32 | 16, 64  |
# | Dropout rate | 0.3 | 0.2, 0.4 |
# | Learning rate | 0.001 | 0.0005, 0.002 |
# | Batch size | 256 | 128, 512 |
#
# Document which configuration gave the best `val_auc` in your metrics JSON.

# %%
## ── 3. Training callbacks ─────────────────────────────────────────────────
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

MODEL_SAVE_PATH = os.path.join(MODEL_DIR, 'lstm_model.keras')

callbacks = [
    EarlyStopping(monitor='val_auc', patience=5, restore_best_weights=True, mode='max', verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5, verbose=1),
    ModelCheckpoint(MODEL_SAVE_PATH, monitor='val_auc', save_best_only=True, mode='max', verbose=1),
]
print("Callbacks configured. Best model will be saved automatically.")
# Out:
# Callbacks configured. Best model will be saved automatically.

# %%
## ── 4. Train the model ────────────────────────────────────────────────────
import time

EPOCHS     = 50
BATCH_SIZE = 256

t0 = time.time()
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    class_weight=class_weights,
    callbacks=callbacks,
    verbose=1,
)
train_time_min = round((time.time() - t0) / 60, 1)
print(f"\nTraining complete in {train_time_min} minutes.")
print(f"Best val AUC: {max(history.history['val_auc']):.4f}")

# Save history
import json
hist_dict = {k: [float(v) for v in vals] for k, vals in history.history.items()}
hist_dict['train_time_min'] = train_time_min
with open(os.path.join(MODEL_DIR, 'lstm_history.json'), 'w') as f:
    json.dump(hist_dict, f, indent=2)
print("History saved:", os.path.join(MODEL_DIR, 'lstm_history.json'))
# Out:
# Epoch 1/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6363 - auc: 0.6729 - loss: 0.6886
# Epoch 1: val_auc improved from None to 0.74505, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 69s 37ms/step - accuracy: 0.6735 - auc: 0.7015 - loss: 0.6418 - val_accuracy: 0.6812 - val_auc: 0.7451 - val_loss: 0.6402 - learning_rate: 0.0010
# Epoch 2/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7084 - auc: 0.7394 - loss: 0.6034
# Epoch 2: val_auc improved from 0.74505 to 0.75831, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 45s 33ms/step - accuracy: 0.7181 - auc: 0.7448 - loss: 0.5970 - val_accuracy: 0.5718 - val_auc: 0.7583 - val_loss: 0.6937 - learning_rate: 0.0010
# Epoch 3/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7214 - auc: 0.7545 - loss: 0.5893
# Epoch 3: val_auc improved from 0.75831 to 0.76761, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 34ms/step - accuracy: 0.7272 - auc: 0.7581 - loss: 0.5850 - val_accuracy: 0.7256 - val_auc: 0.7676 - val_loss: 0.5611 - learning_rate: 0.0010
# Epoch 4/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7325 - auc: 0.7643 - loss: 0.5808
# Epoch 4: val_auc improved from 0.76761 to 0.77032, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 45s 33ms/step - accuracy: 0.7352 - auc: 0.7665 - loss: 0.5771 - val_accuracy: 0.6649 - val_auc: 0.7703 - val_loss: 0.6482 - learning_rate: 0.0010
# Epoch 5/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7334 - auc: 0.7674 - loss: 0.5752
# Epoch 5: val_auc improved from 0.77032 to 0.78081, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 44s 32ms/step - accuracy: 0.7355 - auc: 0.7710 - loss: 0.5725 - val_accuracy: 0.7806 - val_auc: 0.7808 - val_loss: 0.5238 - learning_rate: 0.0010
# Epoch 6/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7282 - auc: 0.7741 - loss: 0.5715
# Epoch 6: val_auc improved from 0.78081 to 0.78521, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 45s 33ms/step - accuracy: 0.7369 - auc: 0.7790 - loss: 0.5641 - val_accuracy: 0.7964 - val_auc: 0.7852 - val_loss: 0.5141 - learning_rate: 0.0010
# Epoch 7/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7373 - auc: 0.7825 - loss: 0.5637
# Epoch 7: val_auc improved from 0.78521 to 0.78977, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 44s 33ms/step - accuracy: 0.7439 - auc: 0.7835 - loss: 0.5592 - val_accuracy: 0.7950 - val_auc: 0.7898 - val_loss: 0.4891 - learning_rate: 0.0010
# Epoch 8/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7419 - auc: 0.7841 - loss: 0.5574
# Epoch 8: val_auc improved from 0.78977 to 0.79218, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 47s 35ms/step - accuracy: 0.7468 - auc: 0.7899 - loss: 0.5518 - val_accuracy: 0.7955 - val_auc: 0.7922 - val_loss: 0.4671 - learning_rate: 0.0010
# Epoch 9/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7470 - auc: 0.7952 - loss: 0.5478
# Epoch 9: val_auc improved from 0.79218 to 0.79747, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 47s 34ms/step - accuracy: 0.7510 - auc: 0.7955 - loss: 0.5455 - val_accuracy: 0.8034 - val_auc: 0.7975 - val_loss: 0.4672 - learning_rate: 0.0010
# Epoch 10/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7584 - auc: 0.7986 - loss: 0.5395
# Epoch 10: val_auc improved from 0.79747 to 0.80069, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 80s 33ms/step - accuracy: 0.7563 - auc: 0.7998 - loss: 0.5408 - val_accuracy: 0.7365 - val_auc: 0.8007 - val_loss: 0.5541 - learning_rate: 0.0010
# Epoch 11/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7585 - auc: 0.8072 - loss: 0.5323
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_auc improved from 0.80069 to 0.80720, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 82s 33ms/step - accuracy: 0.7584 - auc: 0.8041 - loss: 0.5358 - val_accuracy: 0.6653 - val_auc: 0.8072 - val_loss: 0.6255 - learning_rate: 0.0010
# Epoch 12/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7609 - auc: 0.8104 - loss: 0.5257
# Epoch 12: val_auc improved from 0.80720 to 0.81198, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 48s 35ms/step - accuracy: 0.7621 - auc: 0.8106 - loss: 0.5278 - val_accuracy: 0.7633 - val_auc: 0.8120 - val_loss: 0.5021 - learning_rate: 5.0000e-04
# Epoch 13/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7632 - auc: 0.8116 - loss: 0.5260
# Epoch 13: val_auc improved from 0.81198 to 0.81691, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 79s 33ms/step - accuracy: 0.7626 - auc: 0.8128 - loss: 0.5249 - val_accuracy: 0.7514 - val_auc: 0.8169 - val_loss: 0.5166 - learning_rate: 5.0000e-04
# Epoch 14/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7636 - auc: 0.8138 - loss: 0.5288
# Epoch 14: val_auc did not improve from 0.81691
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 82s 33ms/step - accuracy: 0.7640 - auc: 0.8136 - loss: 0.5242 - val_accuracy: 0.8005 - val_auc: 0.8146 - val_loss: 0.4584 - learning_rate: 5.0000e-04
# Epoch 15/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7654 - auc: 0.8181 - loss: 0.5186
# Epoch 15: val_auc did not improve from 0.81691
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 47s 34ms/step - accuracy: 0.7641 - auc: 0.8159 - loss: 0.5210 - val_accuracy: 0.8061 - val_auc: 0.8164 - val_loss: 0.4494 - learning_rate: 5.0000e-04
# Epoch 16/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7679 - auc: 0.8170 - loss: 0.5169
# Epoch 16: val_auc improved from 0.81691 to 0.81751, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 16: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 80s 33ms/step - accuracy: 0.7662 - auc: 0.8160 - loss: 0.5211 - val_accuracy: 0.7413 - val_auc: 0.8175 - val_loss: 0.5507 - learning_rate: 5.0000e-04
# Epoch 17/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7649 - auc: 0.8183 - loss: 0.5194
# Epoch 17: val_auc improved from 0.81751 to 0.81810, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 17: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 45s 33ms/step - accuracy: 0.7664 - auc: 0.8182 - loss: 0.5182 - val_accuracy: 0.8065 - val_auc: 0.8181 - val_loss: 0.4516 - learning_rate: 5.0000e-04
# Epoch 18/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7717 - auc: 0.8224 - loss: 0.5131
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 18: val_auc improved from 0.81810 to 0.82106, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 18: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 82s 33ms/step - accuracy: 0.7682 - auc: 0.8197 - loss: 0.5165 - val_accuracy: 0.7765 - val_auc: 0.8211 - val_loss: 0.4853 - learning_rate: 5.0000e-04
# Epoch 19/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7669 - auc: 0.8214 - loss: 0.5142
# Epoch 19: val_auc improved from 0.82106 to 0.82280, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 19: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 82s 33ms/step - accuracy: 0.7668 - auc: 0.8220 - loss: 0.5137 - val_accuracy: 0.7557 - val_auc: 0.8228 - val_loss: 0.5155 - learning_rate: 2.5000e-04
# Epoch 20/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7699 - auc: 0.8249 - loss: 0.5108
# Epoch 20: val_auc did not improve from 0.82280
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 34ms/step - accuracy: 0.7704 - auc: 0.8251 - loss: 0.5096 - val_accuracy: 0.7743 - val_auc: 0.8223 - val_loss: 0.4969 - learning_rate: 2.5000e-04
# Epoch 21/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7619 - auc: 0.8214 - loss: 0.5136
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 21: val_auc improved from 0.82280 to 0.82421, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 21: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 34ms/step - accuracy: 0.7671 - auc: 0.8241 - loss: 0.5108 - val_accuracy: 0.7864 - val_auc: 0.8242 - val_loss: 0.4712 - learning_rate: 2.5000e-04
# Epoch 22/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7725 - auc: 0.8293 - loss: 0.5029
# Epoch 22: val_auc improved from 0.82421 to 0.82504, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 22: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 82s 34ms/step - accuracy: 0.7728 - auc: 0.8280 - loss: 0.5062 - val_accuracy: 0.7840 - val_auc: 0.8250 - val_loss: 0.4757 - learning_rate: 1.2500e-04
# Epoch 23/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7700 - auc: 0.8280 - loss: 0.5062
# Epoch 23: val_auc improved from 0.82504 to 0.82524, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 23: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 84s 35ms/step - accuracy: 0.7698 - auc: 0.8280 - loss: 0.5059 - val_accuracy: 0.7836 - val_auc: 0.8252 - val_loss: 0.4763 - learning_rate: 1.2500e-04
# Epoch 24/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7722 - auc: 0.8281 - loss: 0.5040
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 24: val_auc improved from 0.82524 to 0.82639, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 24: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 34ms/step - accuracy: 0.7716 - auc: 0.8274 - loss: 0.5065 - val_accuracy: 0.7857 - val_auc: 0.8264 - val_loss: 0.4667 - learning_rate: 1.2500e-04
# Epoch 25/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7699 - auc: 0.8298 - loss: 0.5043
# Epoch 25: val_auc improved from 0.82639 to 0.82682, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 25: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 47s 35ms/step - accuracy: 0.7703 - auc: 0.8292 - loss: 0.5043 - val_accuracy: 0.7879 - val_auc: 0.8268 - val_loss: 0.4659 - learning_rate: 6.2500e-05
# Epoch 26/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7720 - auc: 0.8297 - loss: 0.5036
# Epoch 26: val_auc did not improve from 0.82682
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 83s 35ms/step - accuracy: 0.7713 - auc: 0.8294 - loss: 0.5049 - val_accuracy: 0.7726 - val_auc: 0.8268 - val_loss: 0.4920 - learning_rate: 6.2500e-05
# Epoch 27/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7690 - auc: 0.8250 - loss: 0.5059
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 27: val_auc did not improve from 0.82682
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 79s 33ms/step - accuracy: 0.7702 - auc: 0.8289 - loss: 0.5045 - val_accuracy: 0.7789 - val_auc: 0.8265 - val_loss: 0.4827 - learning_rate: 6.2500e-05
# Epoch 28/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7712 - auc: 0.8299 - loss: 0.5038
# Epoch 28: val_auc did not improve from 0.82682
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 34ms/step - accuracy: 0.7715 - auc: 0.8296 - loss: 0.5040 - val_accuracy: 0.7819 - val_auc: 0.8267 - val_loss: 0.4784 - learning_rate: 3.1250e-05
# Epoch 29/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7712 - auc: 0.8298 - loss: 0.5058
# Epoch 29: val_auc improved from 0.82682 to 0.82698, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 29: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 34ms/step - accuracy: 0.7712 - auc: 0.8305 - loss: 0.5027 - val_accuracy: 0.7820 - val_auc: 0.8270 - val_loss: 0.4741 - learning_rate: 3.1250e-05
# Epoch 30/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7716 - auc: 0.8293 - loss: 0.5046
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 30: val_auc improved from 0.82698 to 0.82708, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 30: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 34ms/step - accuracy: 0.7722 - auc: 0.8309 - loss: 0.5024 - val_accuracy: 0.7833 - val_auc: 0.8271 - val_loss: 0.4688 - learning_rate: 3.1250e-05
# Epoch 31/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7704 - auc: 0.8300 - loss: 0.5030
# Epoch 31: val_auc did not improve from 0.82708
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 82s 34ms/step - accuracy: 0.7713 - auc: 0.8303 - loss: 0.5031 - val_accuracy: 0.7848 - val_auc: 0.8269 - val_loss: 0.4732 - learning_rate: 1.5625e-05
# Epoch 32/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7723 - auc: 0.8313 - loss: 0.5034
# Epoch 32: val_auc did not improve from 0.82708
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 34ms/step - accuracy: 0.7719 - auc: 0.8307 - loss: 0.5028 - val_accuracy: 0.7868 - val_auc: 0.8271 - val_loss: 0.4689 - learning_rate: 1.5625e-05
# Epoch 33/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7712 - auc: 0.8336 - loss: 0.4999
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 33: val_auc did not improve from 0.82708
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 34ms/step - accuracy: 0.7715 - auc: 0.8322 - loss: 0.5005 - val_accuracy: 0.7826 - val_auc: 0.8270 - val_loss: 0.4768 - learning_rate: 1.5625e-05
# Epoch 34/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7725 - auc: 0.8297 - loss: 0.5035
# Epoch 34: val_auc did not improve from 0.82708
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 49s 36ms/step - accuracy: 0.7722 - auc: 0.8307 - loss: 0.5029 - val_accuracy: 0.7868 - val_auc: 0.8270 - val_loss: 0.4708 - learning_rate: 1.0000e-05
# Epoch 35/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7726 - auc: 0.8314 - loss: 0.5007
# Epoch 35: val_auc improved from 0.82708 to 0.82711, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 35: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - accuracy: 0.7722 - auc: 0.8317 - loss: 0.5014 - val_accuracy: 0.7874 - val_auc: 0.8271 - val_loss: 0.4694 - learning_rate: 1.0000e-05
# Epoch 36/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7723 - auc: 0.8321 - loss: 0.5001
# Epoch 36: val_auc improved from 0.82711 to 0.82713, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 36: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 45s 33ms/step - accuracy: 0.7731 - auc: 0.8320 - loss: 0.5011 - val_accuracy: 0.7864 - val_auc: 0.8271 - val_loss: 0.4713 - learning_rate: 1.0000e-05
# Epoch 37/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7726 - auc: 0.8311 - loss: 0.5049
# Epoch 37: val_auc improved from 0.82713 to 0.82723, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 37: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 45s 33ms/step - accuracy: 0.7719 - auc: 0.8316 - loss: 0.5014 - val_accuracy: 0.7842 - val_auc: 0.8272 - val_loss: 0.4740 - learning_rate: 1.0000e-05
# Epoch 38/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7724 - auc: 0.8299 - loss: 0.5007
# Epoch 38: val_auc improved from 0.82723 to 0.82727, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 38: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 45s 33ms/step - accuracy: 0.7723 - auc: 0.8317 - loss: 0.5013 - val_accuracy: 0.7830 - val_auc: 0.8273 - val_loss: 0.4755 - learning_rate: 1.0000e-05
# Epoch 39/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7720 - auc: 0.8291 - loss: 0.5063
# Epoch 39: val_auc did not improve from 0.82727
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 83s 34ms/step - accuracy: 0.7720 - auc: 0.8313 - loss: 0.5015 - val_accuracy: 0.7848 - val_auc: 0.8272 - val_loss: 0.4738 - learning_rate: 1.0000e-05
# Epoch 40/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7735 - auc: 0.8323 - loss: 0.5010
# Epoch 40: val_auc did not improve from 0.82727
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 33ms/step - accuracy: 0.7724 - auc: 0.8321 - loss: 0.5010 - val_accuracy: 0.7816 - val_auc: 0.8272 - val_loss: 0.4785 - learning_rate: 1.0000e-05
# Epoch 41/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7702 - auc: 0.8303 - loss: 0.5010
# Epoch 41: val_auc improved from 0.82727 to 0.82739, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 41: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 34ms/step - accuracy: 0.7718 - auc: 0.8314 - loss: 0.5018 - val_accuracy: 0.7823 - val_auc: 0.8274 - val_loss: 0.4769 - learning_rate: 1.0000e-05
# Epoch 42/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7724 - auc: 0.8325 - loss: 0.5034
# Epoch 42: val_auc improved from 0.82739 to 0.82739, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 42: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 34ms/step - accuracy: 0.7722 - auc: 0.8323 - loss: 0.5009 - val_accuracy: 0.7832 - val_auc: 0.8274 - val_loss: 0.4744 - learning_rate: 1.0000e-05
# Epoch 43/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7727 - auc: 0.8329 - loss: 0.4967
# Epoch 43: val_auc did not improve from 0.82739
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 46s 33ms/step - accuracy: 0.7724 - auc: 0.8317 - loss: 0.5012 - val_accuracy: 0.7850 - val_auc: 0.8273 - val_loss: 0.4734 - learning_rate: 1.0000e-05
# Epoch 44/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7728 - auc: 0.8325 - loss: 0.4970
# Epoch 44: val_auc did not improve from 0.82739
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 48s 36ms/step - accuracy: 0.7731 - auc: 0.8316 - loss: 0.5013 - val_accuracy: 0.7831 - val_auc: 0.8274 - val_loss: 0.4751 - learning_rate: 1.0000e-05
# Epoch 45/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7735 - auc: 0.8314 - loss: 0.4984
# Epoch 45: val_auc improved from 0.82739 to 0.82751, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 45: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 47s 34ms/step - accuracy: 0.7733 - auc: 0.8313 - loss: 0.5016 - val_accuracy: 0.7860 - val_auc: 0.8275 - val_loss: 0.4697 - learning_rate: 1.0000e-05
# Epoch 46/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7721 - auc: 0.8324 - loss: 0.5003
# Epoch 46: val_auc did not improve from 0.82751
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 47s 34ms/step - accuracy: 0.7722 - auc: 0.8320 - loss: 0.5007 - val_accuracy: 0.7883 - val_auc: 0.8275 - val_loss: 0.4673 - learning_rate: 1.0000e-05
# Epoch 47/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7720 - auc: 0.8337 - loss: 0.4997
# Epoch 47: val_auc did not improve from 0.82751
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 50s 36ms/step - accuracy: 0.7724 - auc: 0.8321 - loss: 0.5007 - val_accuracy: 0.7845 - val_auc: 0.8274 - val_loss: 0.4738 - learning_rate: 1.0000e-05
# Epoch 48/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7733 - auc: 0.8329 - loss: 0.4985
# Epoch 48: val_auc did not improve from 0.82751
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 47s 35ms/step - accuracy: 0.7734 - auc: 0.8318 - loss: 0.5013 - val_accuracy: 0.7857 - val_auc: 0.8274 - val_loss: 0.4705 - learning_rate: 1.0000e-05
# Epoch 49/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7728 - auc: 0.8300 - loss: 0.5063
# Epoch 49: val_auc improved from 0.82751 to 0.82760, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 49: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 54s 39ms/step - accuracy: 0.7726 - auc: 0.8320 - loss: 0.5012 - val_accuracy: 0.7810 - val_auc: 0.8276 - val_loss: 0.4782 - learning_rate: 1.0000e-05
# Epoch 50/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7721 - auc: 0.8344 - loss: 0.4969
# Epoch 50: val_auc improved from 0.82760 to 0.82763, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
#
# Epoch 50: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 47s 34ms/step - accuracy: 0.7727 - auc: 0.8343 - loss: 0.4987 - val_accuracy: 0.7829 - val_auc: 0.8276 - val_loss: 0.4736 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 50.
#
# Training complete in 47.3 minutes.
# Best val AUC: 0.8276
# History saved: /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_history.json

# %%
## ── 5. Plot training curves ───────────────────────────────────────────────
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(history.history['loss'],     label='Train loss', linewidth=2)
axes[0].plot(history.history['val_loss'], label='Val loss',   linewidth=2, linestyle='--')
axes[0].set_title('Loss — Binary Cross-Entropy')
axes[0].set_xlabel('Epoch')
axes[0].legend()

axes[1].plot(history.history['auc'],     label='Train AUC', linewidth=2)
axes[1].plot(history.history['val_auc'], label='Val AUC',   linewidth=2, linestyle='--')
axes[1].set_title('AUC-ROC')
axes[1].set_xlabel('Epoch')
axes[1].legend()

plt.tight_layout()
plt.savefig(os.path.join(MODEL_DIR, 'lstm_training_curves.png'), dpi=100, bbox_inches='tight')
plt.show()

# %%
## ── 6. Evaluate on test set ──────────────────────────────────────────────
from sklearn.metrics import (roc_auc_score, f1_score, precision_score,
                              recall_score, confusion_matrix, classification_report)
import json

# Load best saved model (in case training restored weights)
model = tf.keras.models.load_model(MODEL_SAVE_PATH)

y_prob = model.predict(X_test, batch_size=256).flatten()
THRESHOLD = 0.45   # tuned for F1 — adjust if needed
y_pred = (y_prob >= THRESHOLD).astype(int)

auc  = roc_auc_score(y_test, y_prob)
f1   = f1_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec  = recall_score(y_test, y_pred)
cm   = confusion_matrix(y_test, y_pred)

print(f"=== LSTM Test Results ===")
print(f"AUC-ROC   : {auc:.4f}")
print(f"F1 (fraud): {f1:.4f}")
print(f"Precision : {prec:.4f}")
print(f"Recall    : {rec:.4f}")
print(f"Threshold : {THRESHOLD}")
print()
print("Confusion Matrix:")
print(cm)
print()
print(classification_report(y_test, y_pred, target_names=['Legitimate','Fraud']))

# Save metrics JSON — consumed by notebook 04 (evaluation solo)
with open(os.path.join(DATA_PROC, 'meta.json')) as f:
    meta = json.load(f)

metrics = {
    'model': 'lstm',
    'auc_roc': round(auc, 4),
    'f1': round(f1, 4),
    'precision': round(prec, 4),
    'recall': round(rec, 4),
    'threshold': THRESHOLD,
    'confusion_matrix': cm.tolist(),
    'train_time_min': json.load(open(os.path.join(MODEL_DIR, 'lstm_history.json')))['train_time_min'],
    'n_params': int(model.count_params()),
}
with open(os.path.join(MODEL_DIR, 'lstm_metrics.json'), 'w') as f:
    json.dump(metrics, f, indent=2)
print("\nMetrics saved to:", os.path.join(MODEL_DIR, 'lstm_metrics.json'))
print("Share the entire models/lstm/ folder with the Evaluation Solo member.")
# Out:
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# === LSTM Test Results ===
# AUC-ROC   : 0.8305
# F1 (fraud): 0.1774
# Precision : 0.1005
# Recall    : 0.7550
# Threshold : 0.45
#
# Confusion Matrix:
# [[53609 18386]
#  [  667  2055]]
#
#               precision    recall  f1-score   support
#
#   Legitimate       0.99      0.74      0.85     71995
#        Fraud       0.10      0.75      0.18      2722
#
#     accuracy                           0.74     74717
#    macro avg       0.54      0.75      0.51     74717
# weighted avg       0.96      0.74      0.82     74717
#
#
# Metrics saved to: /content/drive/MyDrive/FraudGuard_Parent/models/lstm/lstm_metrics.json
# Share the entire models/lstm/ folder with the Evaluation Solo member.

# %% [markdown]
# ## 7 · Pair 1 Contribution Notes
# > **Both members must fill this section before submission.**
#
# - Member A contributed: *(describe)*
# - Member B contributed: *(describe)*
# - Key design decisions made: *(list)*
# - Challenges encountered: *(list)*
# - Suggestions for improvement: *(list)*
