# %% [markdown]
# # GRU Model — Gated Recurrent Unit
# **Owner:** Pair 2
# **Environment:** Google Colab (GPU recommended for training)
# **Depends on:** `data/processed/` — run `00_data_pipeline.ipynb` first
# **Outputs:**
# - `models/gru/gru_model.keras`
# - `models/gru/gru_history.json`
# - `models/gru/gru_metrics.json`
#
# ---
# ### Setup on Google Colab
# 1. Upload the entire `FraudGuard/` folder to Google Drive
# 2. Open this notebook in Colab → Runtime → Change runtime type → **GPU**
# 3. Run the environment cell below to mount Drive

# %%
## ── 0. Environment & paths ───────────────────────────────────────────────
import os, sys

IN_COLAB = os.path.exists('/content')
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    BASE       = '/content/drive/MyDrive/FraudGuard_Parent'
    # Install any missing packages
    os.system('pip install tensorflow scikit-learn matplotlib -q')
else:
    BASE = os.path.abspath(os.path.join(os.path.dirname(os.path.abspath('__file__')), '..'))

DATA_PROC  = os.path.join(BASE, 'data',   'processed')
MODEL_DIR  = os.path.join(BASE, 'models', 'gru')
os.makedirs(MODEL_DIR, exist_ok=True)

print("BASE      :", BASE)
print("Data      :", DATA_PROC)
print("Model dir :", MODEL_DIR)

import tensorflow as tf
print("TF version:", tf.__version__)
gpus = tf.config.list_physical_devices('GPU')
print("GPUs available:", gpus if gpus else "None (running on CPU)")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# BASE      : /content/drive/MyDrive/FraudGuard_Parent
# Data      : /content/drive/MyDrive/FraudGuard_Parent/data/processed
# Model dir : /content/drive/MyDrive/FraudGuard_Parent/models/gru
# TF version: 2.20.0
# GPUs available: None (running on CPU)

# %%
## ── 1. Load shared processed data ────────────────────────────────────────
import numpy as np, json

X_train = np.load(os.path.join(DATA_PROC, 'X_train.npy'))
X_val   = np.load(os.path.join(DATA_PROC, 'X_val.npy'))
X_test  = np.load(os.path.join(DATA_PROC, 'X_test.npy'))
y_train = np.load(os.path.join(DATA_PROC, 'y_train.npy'))
y_val   = np.load(os.path.join(DATA_PROC, 'y_val.npy'))
y_test  = np.load(os.path.join(DATA_PROC, 'y_test.npy'))

with open(os.path.join(DATA_PROC, 'class_weights.json')) as f:
    class_weights = json.load(f)
    # Convert string keys back to int
    class_weights = {int(k): v for k, v in class_weights.items()}

with open(os.path.join(DATA_PROC, 'meta.json')) as f:
    meta = json.load(f)

SEQ_LEN  = meta['seq_len']
N_FEATS  = meta['n_features']
FEATURES = meta['features']

print(f"X_train : {X_train.shape}")
print(f"X_val   : {X_val.shape}")
print(f"X_test  : {X_test.shape}")
print(f"Class weights: {class_weights}")
# Out:
# X_train : (348676, 5, 15)
# X_val   : (74716, 5, 15)
# X_test  : (74717, 5, 15)
# Class weights: {0: 0.5189063374328813, 1: 13.723079345088161}

# %% [markdown]
# ## 2 · Build the GRU Model
# GRU uses two gates (reset + update) instead of LSTM's three, making it faster to train
# with often comparable performance. Mirror the LSTM structure for a fair comparison.

# %%
## ── 2.1 Architecture ─────────────────────────────────────────────────────
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, BatchNormalization, Masking
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC

model = Sequential([
    Masking(mask_value=0., input_shape=(SEQ_LEN, N_FEATS)),
    GRU(64, return_sequences=True, name='gru_1'),
    BatchNormalization(),
    Dropout(0.3),
    GRU(32, return_sequences=False, name='gru_2'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(1, activation='sigmoid', name='output'),
])

model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss='binary_crossentropy',
    metrics=[AUC(name='auc'), 'accuracy'],
)
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/masking.py:48: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ masking (Masking)               │ (None, 5, 15)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 5, 64)          │        15,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 5, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 5, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 32)             │         9,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,377 (99.13 KB)
#  Trainable params: 25,185 (98.38 KB)
#  Non-trainable params: 192 (768.00 B)

# %% [markdown]
# ### Hyperparameter Options (Pair 2)
# | Parameter | Default | Try also |
# |-----------|---------|----------|
# | GRU units (layer 1) | 64 | 32, 128 |
# | GRU units (layer 2) | 32 | 16, 64  |
# | Dropout rate | 0.3 | 0.2, 0.4 |
# | Learning rate | 0.001 | 0.0005, 0.002 |
# | Batch size | 256 | 128, 512 |
#
# **Note:** GRU typically trains ~25% faster than LSTM. Record actual training time in the metrics JSON.

# %%
## ── 3. Training callbacks ─────────────────────────────────────────────────
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

MODEL_SAVE_PATH = os.path.join(MODEL_DIR, 'gru_model.keras')

callbacks = [
    EarlyStopping(monitor='val_auc', patience=5, restore_best_weights=True, mode='max', verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5, verbose=1),
    ModelCheckpoint(MODEL_SAVE_PATH, monitor='val_auc', save_best_only=True, mode='max', verbose=1),
]
print("Callbacks configured. Best model will be saved automatically.")
# Out:
# Callbacks configured. Best model will be saved automatically.

# %%
## ── 4. Train the model ────────────────────────────────────────────────────
import time

EPOCHS     = 60
BATCH_SIZE = 256

t0 = time.time()
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    class_weight=class_weights,
    callbacks=callbacks,
    verbose=1,
)
train_time_min = round((time.time() - t0) / 60, 1)
print(f"\nTraining complete in {train_time_min} minutes.")
print(f"Best val AUC: {max(history.history['val_auc']):.4f}")

# Save history
import json
hist_dict = {k: [float(v) for v in vals] for k, vals in history.history.items()}
hist_dict['train_time_min'] = train_time_min
with open(os.path.join(MODEL_DIR, 'gru_history.json'), 'w') as f:
    json.dump(hist_dict, f, indent=2)
print("History saved:", os.path.join(MODEL_DIR, 'gru_history.json'))
# Out:
# Epoch 1/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6494 - auc: 0.6881 - loss: 0.6605
# Epoch 1: val_auc improved from None to 0.75592, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 83s 44ms/step - accuracy: 0.6825 - auc: 0.7126 - loss: 0.6308 - val_accuracy: 0.7790 - val_auc: 0.7559 - val_loss: 0.5656 - learning_rate: 0.0010
# Epoch 2/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7150 - auc: 0.7436 - loss: 0.6017
# Epoch 2: val_auc improved from 0.75592 to 0.76524, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 73s 38ms/step - accuracy: 0.7195 - auc: 0.7490 - loss: 0.5935 - val_accuracy: 0.6947 - val_auc: 0.7652 - val_loss: 0.6095 - learning_rate: 0.0010
# Epoch 3/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7333 - auc: 0.7610 - loss: 0.5848
# Epoch 3: val_auc improved from 0.76524 to 0.76966, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 52s 38ms/step - accuracy: 0.7285 - auc: 0.7592 - loss: 0.5845 - val_accuracy: 0.7093 - val_auc: 0.7697 - val_loss: 0.5851 - learning_rate: 0.0010
# Epoch 4/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7354 - auc: 0.7624 - loss: 0.5764
# Epoch 4: val_auc improved from 0.76966 to 0.78055, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 51s 38ms/step - accuracy: 0.7342 - auc: 0.7682 - loss: 0.5756 - val_accuracy: 0.7779 - val_auc: 0.7806 - val_loss: 0.5534 - learning_rate: 0.0010
# Epoch 5/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7302 - auc: 0.7758 - loss: 0.5703
# Epoch 5: val_auc improved from 0.78055 to 0.78524, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 65s 48ms/step - accuracy: 0.7370 - auc: 0.7757 - loss: 0.5684 - val_accuracy: 0.7024 - val_auc: 0.7852 - val_loss: 0.5963 - learning_rate: 0.0010
# Epoch 6/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7459 - auc: 0.7829 - loss: 0.5576
# Epoch 6: val_auc improved from 0.78524 to 0.78956, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 54s 39ms/step - accuracy: 0.7463 - auc: 0.7841 - loss: 0.5598 - val_accuracy: 0.7626 - val_auc: 0.7896 - val_loss: 0.5205 - learning_rate: 0.0010
# Epoch 7/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7446 - auc: 0.7864 - loss: 0.5583
# Epoch 7: val_auc improved from 0.78956 to 0.79495, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 54s 40ms/step - accuracy: 0.7489 - auc: 0.7879 - loss: 0.5555 - val_accuracy: 0.7738 - val_auc: 0.7950 - val_loss: 0.5189 - learning_rate: 0.0010
# Epoch 8/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7398 - auc: 0.7905 - loss: 0.5530
# Epoch 8: val_auc improved from 0.79495 to 0.79535, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 51s 37ms/step - accuracy: 0.7466 - auc: 0.7919 - loss: 0.5510 - val_accuracy: 0.6623 - val_auc: 0.7954 - val_loss: 0.6666 - learning_rate: 0.0010
# Epoch 9/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7500 - auc: 0.7938 - loss: 0.5480
# Epoch 9: val_auc improved from 0.79535 to 0.80005, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 51s 37ms/step - accuracy: 0.7508 - auc: 0.7948 - loss: 0.5475 - val_accuracy: 0.7367 - val_auc: 0.8000 - val_loss: 0.5842 - learning_rate: 0.0010
# Epoch 10/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7569 - auc: 0.8014 - loss: 0.5392
# Epoch 10: val_auc improved from 0.80005 to 0.80210, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 83s 38ms/step - accuracy: 0.7540 - auc: 0.7999 - loss: 0.5416 - val_accuracy: 0.7960 - val_auc: 0.8021 - val_loss: 0.4747 - learning_rate: 0.0010
# Epoch 11/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7548 - auc: 0.8012 - loss: 0.5393
# Epoch 11: val_auc improved from 0.80210 to 0.80260, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 53s 39ms/step - accuracy: 0.7541 - auc: 0.8003 - loss: 0.5409 - val_accuracy: 0.7993 - val_auc: 0.8026 - val_loss: 0.4882 - learning_rate: 0.0010
# Epoch 12/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7522 - auc: 0.8006 - loss: 0.5440
# Epoch 12: val_auc improved from 0.80260 to 0.80401, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 51s 38ms/step - accuracy: 0.7546 - auc: 0.8018 - loss: 0.5387 - val_accuracy: 0.6532 - val_auc: 0.8040 - val_loss: 0.6430 - learning_rate: 0.0010
# Epoch 13/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7615 - auc: 0.8062 - loss: 0.5329
# Epoch 13: val_auc did not improve from 0.80401
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 82s 38ms/step - accuracy: 0.7593 - auc: 0.8052 - loss: 0.5347 - val_accuracy: 0.8109 - val_auc: 0.8022 - val_loss: 0.4696 - learning_rate: 0.0010
# Epoch 14/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7629 - auc: 0.8064 - loss: 0.5281
# Epoch 14: val_auc improved from 0.80401 to 0.80870, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 82s 38ms/step - accuracy: 0.7593 - auc: 0.8074 - loss: 0.5321 - val_accuracy: 0.7763 - val_auc: 0.8087 - val_loss: 0.5037 - learning_rate: 0.0010
# Epoch 15/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7606 - auc: 0.8098 - loss: 0.5273
# Epoch 15: val_auc did not improve from 0.80870
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 52s 38ms/step - accuracy: 0.7617 - auc: 0.8081 - loss: 0.5310 - val_accuracy: 0.7941 - val_auc: 0.8041 - val_loss: 0.4739 - learning_rate: 0.0010
# Epoch 16/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7552 - auc: 0.8072 - loss: 0.5349
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 16: val_auc improved from 0.80870 to 0.81469, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 16: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 51s 37ms/step - accuracy: 0.7595 - auc: 0.8101 - loss: 0.5287 - val_accuracy: 0.7170 - val_auc: 0.8147 - val_loss: 0.5531 - learning_rate: 0.0010
# Epoch 17/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7681 - auc: 0.8160 - loss: 0.5233
# Epoch 17: val_auc improved from 0.81469 to 0.81704, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 17: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 84s 39ms/step - accuracy: 0.7653 - auc: 0.8166 - loss: 0.5213 - val_accuracy: 0.7222 - val_auc: 0.8170 - val_loss: 0.5708 - learning_rate: 5.0000e-04
# Epoch 18/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7639 - auc: 0.8102 - loss: 0.5289
# Epoch 18: val_auc improved from 0.81704 to 0.81779, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 18: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 53s 39ms/step - accuracy: 0.7653 - auc: 0.8172 - loss: 0.5201 - val_accuracy: 0.7867 - val_auc: 0.8178 - val_loss: 0.4695 - learning_rate: 5.0000e-04
# Epoch 19/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7648 - auc: 0.8168 - loss: 0.5210
# Epoch 19: val_auc improved from 0.81779 to 0.81936, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 19: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 54s 40ms/step - accuracy: 0.7662 - auc: 0.8200 - loss: 0.5171 - val_accuracy: 0.7804 - val_auc: 0.8194 - val_loss: 0.4674 - learning_rate: 5.0000e-04
# Epoch 20/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7693 - auc: 0.8234 - loss: 0.5105
# Epoch 20: val_auc did not improve from 0.81936
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 82s 40ms/step - accuracy: 0.7667 - auc: 0.8208 - loss: 0.5163 - val_accuracy: 0.7603 - val_auc: 0.8190 - val_loss: 0.5189 - learning_rate: 5.0000e-04
# Epoch 21/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7661 - auc: 0.8231 - loss: 0.5112
# Epoch 21: val_auc did not improve from 0.81936
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 52s 38ms/step - accuracy: 0.7657 - auc: 0.8215 - loss: 0.5150 - val_accuracy: 0.7813 - val_auc: 0.8180 - val_loss: 0.4793 - learning_rate: 5.0000e-04
# Epoch 22/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7649 - auc: 0.8191 - loss: 0.5134
# Epoch 22: val_auc did not improve from 0.81936
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 55s 40ms/step - accuracy: 0.7672 - auc: 0.8229 - loss: 0.5133 - val_accuracy: 0.8360 - val_auc: 0.8169 - val_loss: 0.3882 - learning_rate: 5.0000e-04
# Epoch 23/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7642 - auc: 0.8225 - loss: 0.5146
# Epoch 23: val_auc improved from 0.81936 to 0.82034, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 23: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 83s 41ms/step - accuracy: 0.7660 - auc: 0.8217 - loss: 0.5144 - val_accuracy: 0.7565 - val_auc: 0.8203 - val_loss: 0.5211 - learning_rate: 5.0000e-04
# Epoch 24/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7677 - auc: 0.8239 - loss: 0.5109
# Epoch 24: val_auc improved from 0.82034 to 0.82202, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 24: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 78s 38ms/step - accuracy: 0.7667 - auc: 0.8238 - loss: 0.5122 - val_accuracy: 0.8028 - val_auc: 0.8220 - val_loss: 0.4345 - learning_rate: 5.0000e-04
# Epoch 25/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7648 - auc: 0.8247 - loss: 0.5123
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 25: val_auc did not improve from 0.82202
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 84s 39ms/step - accuracy: 0.7676 - auc: 0.8242 - loss: 0.5117 - val_accuracy: 0.7849 - val_auc: 0.8205 - val_loss: 0.4798 - learning_rate: 5.0000e-04
# Epoch 26/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7633 - auc: 0.8256 - loss: 0.5103
# Epoch 26: val_auc improved from 0.82202 to 0.82461, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 26: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 52s 38ms/step - accuracy: 0.7655 - auc: 0.8281 - loss: 0.5065 - val_accuracy: 0.7626 - val_auc: 0.8246 - val_loss: 0.4946 - learning_rate: 2.5000e-04
# Epoch 27/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7684 - auc: 0.8269 - loss: 0.5064
# Epoch 27: val_auc did not improve from 0.82461
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 51s 38ms/step - accuracy: 0.7681 - auc: 0.8291 - loss: 0.5055 - val_accuracy: 0.7172 - val_auc: 0.8246 - val_loss: 0.5672 - learning_rate: 2.5000e-04
# Epoch 28/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7682 - auc: 0.8276 - loss: 0.5072
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 28: val_auc did not improve from 0.82461
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 84s 39ms/step - accuracy: 0.7690 - auc: 0.8287 - loss: 0.5055 - val_accuracy: 0.8003 - val_auc: 0.8240 - val_loss: 0.4466 - learning_rate: 2.5000e-04
# Epoch 29/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7706 - auc: 0.8314 - loss: 0.5019
# Epoch 29: val_auc improved from 0.82461 to 0.82683, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 29: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 52s 38ms/step - accuracy: 0.7711 - auc: 0.8292 - loss: 0.5050 - val_accuracy: 0.7564 - val_auc: 0.8268 - val_loss: 0.5018 - learning_rate: 1.2500e-04
# Epoch 30/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7740 - auc: 0.8356 - loss: 0.4955
# Epoch 30: val_auc improved from 0.82683 to 0.82728, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 30: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 84s 39ms/step - accuracy: 0.7726 - auc: 0.8332 - loss: 0.5001 - val_accuracy: 0.7620 - val_auc: 0.8273 - val_loss: 0.4948 - learning_rate: 1.2500e-04
# Epoch 31/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7689 - auc: 0.8308 - loss: 0.5028
# Epoch 31: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 31: val_auc did not improve from 0.82728
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 52s 38ms/step - accuracy: 0.7696 - auc: 0.8321 - loss: 0.5019 - val_accuracy: 0.7760 - val_auc: 0.8265 - val_loss: 0.4808 - learning_rate: 1.2500e-04
# Epoch 32/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7725 - auc: 0.8353 - loss: 0.5018
# Epoch 32: val_auc did not improve from 0.82728
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 81s 38ms/step - accuracy: 0.7705 - auc: 0.8324 - loss: 0.5012 - val_accuracy: 0.7782 - val_auc: 0.8272 - val_loss: 0.4712 - learning_rate: 6.2500e-05
# Epoch 33/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7714 - auc: 0.8332 - loss: 0.5025
# Epoch 33: val_auc improved from 0.82728 to 0.82763, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 33: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 54s 40ms/step - accuracy: 0.7713 - auc: 0.8337 - loss: 0.4996 - val_accuracy: 0.7725 - val_auc: 0.8276 - val_loss: 0.4824 - learning_rate: 6.2500e-05
# Epoch 34/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7713 - auc: 0.8324 - loss: 0.5031
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 34: val_auc did not improve from 0.82763
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 80s 38ms/step - accuracy: 0.7712 - auc: 0.8330 - loss: 0.5006 - val_accuracy: 0.7860 - val_auc: 0.8274 - val_loss: 0.4639 - learning_rate: 6.2500e-05
# Epoch 35/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7722 - auc: 0.8323 - loss: 0.4998
# Epoch 35: val_auc did not improve from 0.82763
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 52s 38ms/step - accuracy: 0.7719 - auc: 0.8336 - loss: 0.4998 - val_accuracy: 0.7794 - val_auc: 0.8276 - val_loss: 0.4735 - learning_rate: 3.1250e-05
# Epoch 36/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7705 - auc: 0.8319 - loss: 0.5070
# Epoch 36: val_auc did not improve from 0.82763
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 52s 38ms/step - accuracy: 0.7702 - auc: 0.8331 - loss: 0.5007 - val_accuracy: 0.7915 - val_auc: 0.8273 - val_loss: 0.4523 - learning_rate: 3.1250e-05
# Epoch 37/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7716 - auc: 0.8307 - loss: 0.4974
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 37: val_auc improved from 0.82763 to 0.82783, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 37: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 84s 40ms/step - accuracy: 0.7724 - auc: 0.8333 - loss: 0.4999 - val_accuracy: 0.7785 - val_auc: 0.8278 - val_loss: 0.4716 - learning_rate: 3.1250e-05
# Epoch 38/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7717 - auc: 0.8373 - loss: 0.4930
# Epoch 38: val_auc did not improve from 0.82783
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 53s 39ms/step - accuracy: 0.7718 - auc: 0.8342 - loss: 0.4990 - val_accuracy: 0.7844 - val_auc: 0.8276 - val_loss: 0.4648 - learning_rate: 1.5625e-05
# Epoch 39/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7700 - auc: 0.8311 - loss: 0.5005
# Epoch 39: val_auc did not improve from 0.82783
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 54s 40ms/step - accuracy: 0.7718 - auc: 0.8341 - loss: 0.4987 - val_accuracy: 0.7890 - val_auc: 0.8274 - val_loss: 0.4582 - learning_rate: 1.5625e-05
# Epoch 40/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7703 - auc: 0.8330 - loss: 0.4962
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 40: val_auc did not improve from 0.82783
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 52s 38ms/step - accuracy: 0.7711 - auc: 0.8342 - loss: 0.4987 - val_accuracy: 0.7803 - val_auc: 0.8278 - val_loss: 0.4713 - learning_rate: 1.5625e-05
# Epoch 41/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7720 - auc: 0.8304 - loss: 0.5036
# Epoch 41: val_auc improved from 0.82783 to 0.82785, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 41: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 85s 40ms/step - accuracy: 0.7727 - auc: 0.8332 - loss: 0.4999 - val_accuracy: 0.7812 - val_auc: 0.8279 - val_loss: 0.4693 - learning_rate: 1.0000e-05
# Epoch 42/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7712 - auc: 0.8310 - loss: 0.5045
# Epoch 42: val_auc improved from 0.82785 to 0.82800, saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
#
# Epoch 42: finished saving model to /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_model.keras
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 53s 39ms/step - accuracy: 0.7708 - auc: 0.8345 - loss: 0.4984 - val_accuracy: 0.7774 - val_auc: 0.8280 - val_loss: 0.4743 - learning_rate: 1.0000e-05
# Epoch 43/50
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7727 - auc: 0.8351 - loss: 0.4977
# Epoch 43: val_auc did not improve from 0.82800
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 52s 38ms/step - accuracy: 0.7714 - auc: 0.8335 - loss: 0.4998 - val_accuracy: 0.7812 - val_auc: 0.8279 - val_loss: 0.4703 - learning_rate: 1.0000e-05
# Epoch 44/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7714 - auc: 0.8339 - loss: 0.4971
# Epoch 44: val_auc did not improve from 0.82800
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 52s 38ms/step - accuracy: 0.7715 - auc: 0.8345 - loss: 0.4988 - val_accuracy: 0.7821 - val_auc: 0.8279 - val_loss: 0.4687 - learning_rate: 1.0000e-05
# Epoch 45/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7727 - auc: 0.8354 - loss: 0.4949
# Epoch 45: val_auc did not improve from 0.82800
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 55s 40ms/step - accuracy: 0.7723 - auc: 0.8338 - loss: 0.4992 - val_accuracy: 0.7809 - val_auc: 0.8278 - val_loss: 0.4707 - learning_rate: 1.0000e-05
# Epoch 46/50
# 1362/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7723 - auc: 0.8350 - loss: 0.4998
# Epoch 46: val_auc did not improve from 0.82800
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 80s 38ms/step - accuracy: 0.7723 - auc: 0.8328 - loss: 0.5005 - val_accuracy: 0.7840 - val_auc: 0.8279 - val_loss: 0.4651 - learning_rate: 1.0000e-05
# Epoch 47/50
# 1361/1363 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7701 - auc: 0.8350 - loss: 0.4951
# Epoch 47: val_auc did not improve from 0.82800
# 1363/1363 ━━━━━━━━━━━━━━━━━━━━ 52s 38ms/step - accuracy: 0.7706 - auc: 0.8336 - loss: 0.4995 - val_accuracy: 0.7805 - val_auc: 0.8280 - val_loss: 0.4699 - learning_rate: 1.0000e-05
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 42.
#
# Training complete in 49.7 minutes.
# Best val AUC: 0.8280
# History saved: /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_history.json

# %%
## ── 5. Plot training curves ───────────────────────────────────────────────
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(history.history['loss'],     label='Train loss', linewidth=2)
axes[0].plot(history.history['val_loss'], label='Val loss',   linewidth=2, linestyle='--')
axes[0].set_title('Loss — Binary Cross-Entropy')
axes[0].set_xlabel('Epoch')
axes[0].legend()

axes[1].plot(history.history['auc'],     label='Train AUC', linewidth=2)
axes[1].plot(history.history['val_auc'], label='Val AUC',   linewidth=2, linestyle='--')
axes[1].set_title('AUC-ROC')
axes[1].set_xlabel('Epoch')
axes[1].legend()

plt.tight_layout()
plt.savefig(os.path.join(MODEL_DIR, 'gru_training_curves.png'), dpi=100, bbox_inches='tight')
plt.show()

# %%
## ── 6. Evaluate on test set ──────────────────────────────────────────────
from sklearn.metrics import (roc_auc_score, f1_score, precision_score,
                              recall_score, confusion_matrix, classification_report)
import json

# Load best saved model (in case training restored weights)
model = tf.keras.models.load_model(MODEL_SAVE_PATH)

y_prob = model.predict(X_test, batch_size=256).flatten()
THRESHOLD = 0.45   # tuned for F1 — adjust if needed
y_pred = (y_prob >= THRESHOLD).astype(int)

auc  = roc_auc_score(y_test, y_prob)
f1   = f1_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec  = recall_score(y_test, y_pred)
cm   = confusion_matrix(y_test, y_pred)

print(f"=== GRU Test Results ===")
print(f"AUC-ROC   : {auc:.4f}")
print(f"F1 (fraud): {f1:.4f}")
print(f"Precision : {prec:.4f}")
print(f"Recall    : {rec:.4f}")
print(f"Threshold : {THRESHOLD}")
print()
print("Confusion Matrix:")
print(cm)
print()
print(classification_report(y_test, y_pred, target_names=['Legitimate','Fraud']))

# Save metrics JSON — consumed by notebook 04 (evaluation solo)
with open(os.path.join(DATA_PROC, 'meta.json')) as f:
    meta = json.load(f)

metrics = {
    'model': 'gru',
    'auc_roc': round(auc, 4),
    'f1': round(f1, 4),
    'precision': round(prec, 4),
    'recall': round(rec, 4),
    'threshold': THRESHOLD,
    'confusion_matrix': cm.tolist(),
    'train_time_min': json.load(open(os.path.join(MODEL_DIR, 'gru_history.json')))['train_time_min'],
    'n_params': int(model.count_params()),
}
with open(os.path.join(MODEL_DIR, 'gru_metrics.json'), 'w') as f:
    json.dump(metrics, f, indent=2)
print("\nMetrics saved to:", os.path.join(MODEL_DIR, 'gru_metrics.json'))
print("Share the entire models/gru/ folder with the Evaluation Solo member.")
# Out:
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step
# === GRU Test Results ===
# AUC-ROC   : 0.8323
# F1 (fraud): 0.1788
# Precision : 0.1013
# Recall    : 0.7619
# Threshold : 0.45
#
# Confusion Matrix:
# [[53590 18405]
#  [  648  2074]]
#
#               precision    recall  f1-score   support
#
#   Legitimate       0.99      0.74      0.85     71995
#        Fraud       0.10      0.76      0.18      2722
#
#     accuracy                           0.74     74717
#    macro avg       0.54      0.75      0.51     74717
# weighted avg       0.96      0.74      0.82     74717
#
#
# Metrics saved to: /content/drive/MyDrive/FraudGuard_Parent/models/gru/gru_metrics.json
# Share the entire models/gru/ folder with the Evaluation Solo member.

# %% [markdown]
# ## 7 · Pair 2 Contribution Notes
# > **Both members must fill this section before submission.**
#
# - Member A contributed: *(describe)*
# - Member B contributed: *(describe)*
# - Key design decisions made: *(list)*
# - Challenges encountered: *(list)*
# - Suggestions for improvement: *(list)*
